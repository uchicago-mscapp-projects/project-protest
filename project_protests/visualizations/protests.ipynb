# %%
import pandas as pd 
import plotly.express as px 
import os

# %%
def city_counts():
    """
    """
    df = protest_data()
    df_pivot = pd.pivot_table(df, index='Year', values='Date',
                          aggfunc='count', margins=True, margins_name='Count')
    df_pivot.drop(index='Count', inplace=True)
    df_pivot.rename({'Date':'Count'}, axis='columns', inplace=True)
    fig = px.line(df_pivot, y='Count', template="simple_white")
    # fig.update_layout(xaxis_showgrid=False, yaxis_showgrid=False)

    return fig.show()

city_counts()
# Out:
# /tmp/user/23109/ipykernel_1657921/1319480803.py:3: DtypeWarning:
#
# Columns (0,1,6,7,8,9) have mixed types. Specify dtype option on import or set low_memory=False.
#
# /tmp/user/23109/ipykernel_1657921/1319480803.py:5: FutureWarning:
#
# In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
# <div>                            <div id="279bd409-839a-4f13-af25-44f9b4f6ff7f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("279bd409-839a-4f13-af25-44f9b4f6ff7f")) {                    Plotly.newPlot(                        "279bd409-839a-4f13-af25-44f9b4f6ff7f",                        [{"hovertemplate":"Year=%{x}<br>Count=%{y}<extra></extra>","legendgroup":"","line":{"color":"#1F77B4","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["15","16","17","18","19","20","21","22","23"],"xaxis":"x","y":[1,2,8420,10434,6013,19922,5319,4311,764],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2d"}],"histogram":[{"marker":{"line":{"color":"white","width":0.6}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","t ...

# %%
def protest_cities_hist():
    """
    """
    df = protest_data()
    dfg = df.groupby(['City_Town']).size().to_frame().sort_values([0], ascending = False).head(10).reset_index()
    cities = list(dfg['City_Town'])

    df['Count'] = 1
    df = df.loc[df['City_Town'].isin(cities)]

    df_pivot = pd.pivot_table(df, index= ['Year', 'City_Town'], values='Date',
            aggfunc='count', margins=True, margins_name='Count')
    df_pivot.drop(index='Count', inplace=True)
    df_pivot.rename({'Date':'Count'}, axis='columns', inplace=True)


    df.apply(pd.to_numeric, errors='ignore')
    fig = px.histogram(df, x="Year", y="Count", color="City_Town",
            width=600, height=400,
            labels={ # replaces default labels by column name
                "Year": "Year",  "Count": "Count", "City_Town": "City"
            },
            template="simple_white", color_discrete_sequence= px.colors.sequential.Plasma_r
            )
    return fig.show()

protest_cities_hist()
# Out:
# /tmp/user/23109/ipykernel_1657921/1319480803.py:3: DtypeWarning:
#
# Columns (0,1,6,7,8,9) have mixed types. Specify dtype option on import or set low_memory=False.
#
# /tmp/user/23109/ipykernel_1657921/1319480803.py:5: FutureWarning:
#
# In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
# <div>                            <div id="4d20a34b-b3e1-42e2-993d-020918c7ad15" class="plotly-graph-div" style="height:400px; width:600px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4d20a34b-b3e1-42e2-993d-020918c7ad15")) {                    Plotly.newPlot(                        "4d20a34b-b3e1-42e2-993d-020918c7ad15",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":
    df['Count'] = 1
    df = df.loc[df['City_Town'].isin(cities)]
    # pivot data by year 
    df_pivot = df.groupby(['Year', 'City_Town']).count().reset_index()
    fig = px.line(df_pivot, x='Year', y='Count', color='City_Town', template="simple_white", color_discrete_sequence= px.colors.sequential.Plasma_r)

    # pd.pivot_table(df, index= ['Year', 'City_Town'], values='Date',
    # #         aggfunc='count', margins=True, margins_name='Count')
    # df_pivot.drop(index='Count', inplace=True)
    # df_pivot.rename({'Date':'Count'}, axis='columns', inplace=True)
    return fig.show()

protest_cities_line()
# Out:
# /tmp/user/23109/ipykernel_1657921/1319480803.py:3: DtypeWarning:
#
# Columns (0,1,6,7,8,9) have mixed types. Specify dtype option on import or set low_memory=False.
#
# /tmp/user/23109/ipykernel_1657921/1319480803.py:5: FutureWarning:
#
# In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
# <div>                            <div id="cb0e3649-f3bf-494d-8e76-b08b6bc7b805" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cb0e3649-f3bf-494d-8e76-b08b6bc7b805")) {                    Plotly.newPlot(                        "cb0e3649-f3bf-494d-8e76-b08b6bc7b805",                        [{"hovertemplate":"City_Town=Boston<br>Year=%{x}<br>Count=%{y}<extra></extra>","legendgroup":"Boston","line":{"color":"#f0f921","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Boston","orientation":"v","showlegend":true,"x":["17","18","19","20"],"xaxis":"x","y":[79,91,64,119],"yaxis":"y","type":"scatter"},{"hovertemplate":"City_Town=Chicago<br>Year=%{x}<br>Count=%{y}<extra></extra>","legendgroup":"Chicago","line":{"color":"#fdca26","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Chicago","orientation":"v","showlegend":true,"x":["17","18","19","20"],"xaxis":"x","y":[108,125,55,174],"yaxis":"y","type":"scatter"},{"hovertemplate":"City_Town=Los Angeles<br>Year=%{x}<br>Count=%{y}<extra></extra>","legendgroup":"Los Angeles","line":{"color":"#fb9f3a","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Los Angeles","orientation":"v","showlegend":true,"x":["17","18","19","20"],"xaxis":"x","y":[138,181,130,235],"yaxis":"y","type":"scatter"},{"hovertemplate":"City_Town=New York<br>Year=%{x}<br>Count=%{y}<extra></extra>","legendgroup":"New York","line":{"color":"#ed7953","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"New York","orientation":"v","showlegend":true,"x":["17","18","19","20"],"xaxis":"x","y":[175,344,152,849],"yaxis":"y","type":"scatter"},{"hovertemplate":"City_Town=Philadelphia<br>Year=%{x}<br>Count=%{y}<extra></extra>","legendgroup":"Philadelphia","line":{"color":"#d8576b","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Philadelphia","orientation":"v","showlegend":true,"x":["17","18","19","20"],"xaxis":"x","y":[97,98,36,180],"yaxis":"y","type":"scatter"},{"hovertemplate":"City_Town=Portland<br>Year=%{x}<br>Count=%{y}<extra></extra>","legendgroup":"Portland","line":{"color":"#bd3786","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Portland","orientation":"v","showlegend":true,"x":["17","18","19","20"],"xaxis":"x","y":[92,131,62,240],"yaxis":"y","type":"scatter"},{"hovertemplate":"City_Town=San Diego<br>Year=%{x}<br>Count=%{y}<extra></extra>","legendgroup":"San Diego","line":{"color":"#9c179e","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"San Diego","orientation":"v","showlegend":true,"x":["17","18","19","20"],"xaxis":"x","y":[69,76,42,108],"yaxis":"y","type":"scatter"},{"hovertemplate":"City_Town=San Francisco<br>Year=%{x}<br>Count=%{y}<extra></extra>","legendgroup":"San Francisco","line":{"color":"#7201a8","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"San Francisco","orientation":"v","showlegend":true,"x":["17","18","19","20"],"xaxis":"x","y":[74,119,70,134],"yaxis":"y","type":"scatter"},{"hovertemplate":"City_Town=Seattle<br>Year=%{x}<br>Count=%{y}<extra></extra>","legendgroup":"Seattle","line":{"color":"#46039f","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Seattle","orientation":"v","showlegend":true,"x":["17","18","19","20"],"xaxis":"x","y":[67,86,47,242],"yaxis":"y","type":"scatter"},{"hovertemplate":"City_Town=Washington<br>Year=%{x}<br>Count=%{y}<extra></extra>","legendgroup":"Washington","line":{"color":"#0d0887","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Washington","orientation":"v","showlegend":true,"x":["17","18","19","20","21"],"xaxis":"x","y":[161,203,106,260,1],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","wi ...
